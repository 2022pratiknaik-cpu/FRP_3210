# %% [markdown]
# ## 1. Install Required Libraries
# Run this cell to install all necessary libraries into the exact Python environment running this notebook.

# %%
import sys
print(f"Installing packages for Python executable: {sys.executable}")
# !{sys.executable} -m pip install opencv-python mediapipe numpy tensorflow
# Out:
# Installing packages for Python executable: c:\Program Files\Python312\python.exe
# 'c:\Program' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## 2. Import Libraries & Verify Installation
# Run this cell to ensure everything was installed correctly.

# %%
import cv2
import mediapipe as mp
import numpy as np
import tensorflow as tf

print("OpenCV version:", cv2.__version__)
print("MediaPipe installed successfully")
print("NumPy version:", np.__version__)
print("TensorFlow version:", tf.__version__)
print("\nAll libraries installed and imported successfully!")
# Out:
# OpenCV version: 4.11.0
# MediaPipe installed successfully
# NumPy version: 1.26.4
# TensorFlow version: 2.16.1
#
# All libraries installed and imported successfully!

# %% [markdown]
# ## 3. Inference Test
# This cell sets up a webcam feed and loads the provided `keras_model.h5` and `labels.txt` to test inference.

# %%
from tensorflow.keras.models import load_model

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("keras_model.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# Initialize webcam
cap = cv2.VideoCapture(0)

while True:
    # Grab the webcamera's image
    ret, image = cap.read()
    if not ret:
        print("Failed to grab frame")
        break

    # Resize the raw image into (224-height,224-width) pixels
    image_resized = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Make the image a numpy array and reshape it to the models input shape
    image_array = np.asarray(image_resized, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize the image array
    image_array = (image_array / 127.5) - 1

    # Predicts the model
    prediction = model.predict(image_array, verbose=0)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Display prediction and confidence score
    cv2.putText(image, f"Class: {class_name[2:-1]}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(image, f"Confidence: {str(np.round(confidence_score * 100))[:-2]}%", (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Show the image in a window
    cv2.imshow("Webcam Image", image)

    # Listen to the keyboard for presses
    keyboard_input = cv2.waitKey(1)

    # 27 is the ASCII for the esc key on your keyboard
    if keyboard_input == 27 or keyboard_input == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 7
#       4 np.set_printoptions(suppress=True)
#       6 # Load the model
# ----> 7 model = load_model("keras_model.h5", compile=False)
#       9 # Load the labels
#      10 class_names = open("labels.txt", "r").readlines()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\saving\saving_api.py:195, in load_model(filepath, custom_objects, compile, safe_mode)
#     188     return saving_lib.load_model(
#     189         filepath,
#     190         custom_objects=custom_objects,
#     191         compile=compile,
#     192         safe_mode=safe_mode,
#     193     )
#     194 if str(filepath).endswith((".h5", ".hdf5")):
# --> 195     return legacy_h5_format.load_model_from_hdf5(
#     196         filepath,
#     197         custom_objects=custom_objects,
#     198         compile=compile,
# ...
